# %%
project_name = "TrialScope"
condition = "Type 2 diabetes"
question = "Who is represented in clinical trials?"

print(f"{project_name} investigates {condition} clinical trials.")
print(question)
# Out:
# TrialScope investigates Type 2 diabetes clinical trials.
# Who is represented in clinical trials?

# %%
example_enrolment = [48, 120, 75, 210, 90]

total_enrolment = sum(example_enrolment)
average_enrolment = total_enrolment / len(example_enrolment)

print(f"Total participants: {total_enrolment}")
print(f"Average trial size: {average_enrolment}")
# Out:
# Total participants: 543
# Average trial size: 108.6
